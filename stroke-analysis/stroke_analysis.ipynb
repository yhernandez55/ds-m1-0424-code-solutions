# %%
import numpy as np
import pandas as pd

# %%
stroke = pd.read_csv("/content/healthcare-dataset-stroke-data.csv")
stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
stroke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# 1
stroke.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
# 2
stroke_type = stroke.select_dtypes(include='float')
stroke_type.head()
# Out:
#     age  avg_glucose_level   bmi
# 0  67.0             228.69  36.6
# 1  61.0             202.21   NaN
# 2  80.0             105.92  32.5
# 3  49.0             171.23  34.4
# 4  79.0             174.12  24.0

# %%
# 3
grouped_stroke = stroke.groupby('stroke')
grouped_stroke.head()
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 0     9046    Male  67.0             0              1          Yes
# 1    51676  Female  61.0             0              0          Yes
# 2    31112    Male  80.0             0              1          Yes
# 3    60182  Female  49.0             0              0          Yes
# 4     1665  Female  79.0             1              0          Yes
# 249  30669    Male   3.0             0              0           No
# 250  30468    Male  58.0             1              0          Yes
# 251  16523  Female   8.0             0              0           No
# 252  56543  Female  70.0             0              0          Yes
# 253  46136    Male  14.0             0              0           No
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0          Private          Urban             228.69  36.6  formerly smoked
# ...

# %%
# 4
stroke1 = grouped_stroke.get_group(1)
stroke1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# 5
stroke_float = stroke.select_dtypes(include = 'float').describe()
stroke_float
# Out:
#                age  avg_glucose_level          bmi
# count  5110.000000        5110.000000  4909.000000
# mean     43.226614         106.147677    28.893237
# std      22.612647          45.283560     7.854067
# min       0.080000          55.120000    10.300000
# 25%      25.000000          77.245000    23.500000
# 50%      45.000000          91.885000    28.100000
# 75%      61.000000         114.090000    33.100000
# max      82.000000         271.740000    97.600000

# %%
# 6
stroke.describe(include='int', percentiles=[.25, .5, .75])
# Out:
#                  id  hypertension  heart_disease       stroke
# count   5110.000000   5110.000000    5110.000000  5110.000000
# mean   36517.829354      0.097456       0.054012     0.048728
# std    21161.721625      0.296607       0.226063     0.215320
# min       67.000000      0.000000       0.000000     0.000000
# 25%    17741.250000      0.000000       0.000000     0.000000
# 50%    36932.000000      0.000000       0.000000     0.000000
# 75%    54682.000000      0.000000       0.000000     0.000000
# max    72940.000000      1.000000       1.000000     1.000000

# %%
# 7
df = stroke.groupby(['hypertension', 'heart_disease']).describe()
df
# Out:
#                                 id                                     \
#                              count          mean           std    min
# hypertension heart_disease
# 0            0              4400.0  36566.362727  21127.382867   67.0
#              1               212.0  34973.608491  21601.596413  967.0
# 1            0               434.0  36098.767281  21386.880653  365.0
#              1                64.0  41138.156250  20263.522440  239.0
#
#                                                                      age  \
#                                  25%      50%       75%      max   count
# hypertension heart_disease
# 0            0              17917.75  37093.0  54575.25  72940.0  4400.0
#              1              15118.75  33561.0  53849.00  72715.0   212.0
# 1            0              17229.25  34969.0  55801.25  72918.0   434.0
#              1              27999.50  41355.5  56166.50  72310.0    64.0
#
# ...

# %%
# 8
df1 = df.get_group((1,1))
df1
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 6     53882    Male  74.0             1              1          Yes
# 35      712  Female  82.0             1              1           No
# 115   53401    Male  71.0             1              1           No
# 143   37651  Female  69.0             1              1           No
# 171   60739  Female  79.0             1              1           No
# ...     ...     ...   ...           ...            ...          ...
# 4590  19271  Female  82.0             1              1          Yes
# 4638  72160    Male  72.0             1              1          Yes
# 4684  49894  Female  78.0             1              1          Yes
# 4784  70497  Female  81.0             1              1          Yes
# 4855  42563  Female  57.0             1              1          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# 9
df['id'].nunique()
# Out:
# hypertension  heart_disease
# 0             0                4400
#               1                 212
# 1             0                 434
#               1                  64
# Name: id, dtype: int64

# %%
# 10
df['stroke'].describe()[['mean', 'std']]
# Out:
#                                 mean       std
# hypertension heart_disease
# 0            0              0.033864  0.180899
#              1              0.160377  0.367824
# 1            0              0.122120  0.327802
#              1              0.203125  0.405505
