# %%
import pandas as pd

# %%
event = pd.read_csv('/content/event_type.csv')
log = pd.read_csv('/content/log_feature.csv')
resources = pd.read_csv('/content/resource_type.csv')
sample = pd.read_csv('/content/sample_submission.csv')
severity = pd.read_csv('/content/severity_type.csv')
test = pd.read_csv('/content/test.csv')
train = pd.read_csv('/content/train.csv')

# %%
event
# Out:
#          id     event_type
# 0      6597  event_type 11
# 1      8011  event_type 15
# 2      2597  event_type 15
# 3      5022  event_type 15
# 4      5022  event_type 11
# ...     ...            ...
# 31165  3761  event_type 11
# 31166  8720  event_type 11
# 31167  6488  event_type 11
# 31168   878  event_type 11
# 31169  4464  event_type 11
#
# [31170 rows x 2 columns]

# %%
log
# Out:
#          id  log_feature  volume
# 0      6597   feature 68       6
# 1      8011   feature 68       7
# 2      2597   feature 68       1
# 3      5022  feature 172       2
# 4      5022   feature 56       1
# ...     ...          ...     ...
# 58666  8720  feature 209       1
# 58667  6488   feature 54       3
# 58668   878   feature 62       1
# 58669  4464  feature 209       1
# 58670  4464   feature 87       2
#
# [58671 rows x 3 columns]

# %%
resources
# Out:
#          id    resource_type
# 0      6597  resource_type 8
# 1      8011  resource_type 8
# 2      2597  resource_type 8
# 3      5022  resource_type 8
# 4      6852  resource_type 8
# ...     ...              ...
# 21071  3761  resource_type 8
# 21072  8720  resource_type 8
# 21073  6488  resource_type 8
# 21074   878  resource_type 8
# 21075  4464  resource_type 8
#
# [21076 rows x 2 columns]

# %%
sample
# Out:
#           id  predict_0  predict_1  predict_2
# 0      11066          0          1          0
# 1      18000          0          1          0
# 2      16964          0          1          0
# 3       4795          0          1          0
# 4       3392          0          1          0
# ...      ...        ...        ...        ...
# 11166  14806          0          1          0
# 11167   1825          0          1          0
# 11168   2374          0          1          0
# 11169   7277          0          1          0
# 11170   9886          0          1          0
#
# [11171 rows x 4 columns]

# %%
severity
# Out:
#          id    severity_type
# 0      6597  severity_type 2
# 1      8011  severity_type 2
# 2      2597  severity_type 2
# 3      5022  severity_type 1
# 4      6852  severity_type 1
# ...     ...              ...
# 18547  3761  severity_type 1
# 18548  8720  severity_type 1
# 18549  6488  severity_type 2
# 18550   878  severity_type 2
# 18551  4464  severity_type 1
#
# [18552 rows x 2 columns]

# %%
test
# Out:
#           id       location
# 0      11066   location 481
# 1      18000   location 962
# 2      16964   location 491
# 3       4795   location 532
# 4       3392   location 600
# ...      ...            ...
# 11166  14806  location 1073
# 11167   1825    location 11
# 11168   2374   location 917
# 11169   7277   location 208
# 11170   9886   location 438
#
# [11171 rows x 2 columns]

# %%
train
# Out:
#          id       location  fault_severity
# 0     14121   location 118               1
# 1      9320    location 91               0
# 2     14394   location 152               1
# 3      8218   location 931               1
# 4     14804   location 120               0
# ...     ...            ...             ...
# 7376    870   location 167               0
# 7377  18068   location 106               0
# 7378  14111  location 1086               2
# 7379  15189     location 7               0
# 7380  17067   location 885               0
#
# [7381 rows x 3 columns]

# %%
# 1
merge_tables = pd.concat([train, event, severity,resources,log],axis=0)
merge_tables
# Out:
#           id      location  fault_severity event_type severity_type  \
# 0      14121  location 118             1.0        NaN           NaN
# 1       9320   location 91             0.0        NaN           NaN
# 2      14394  location 152             1.0        NaN           NaN
# 3       8218  location 931             1.0        NaN           NaN
# 4      14804  location 120             0.0        NaN           NaN
# ...      ...           ...             ...        ...           ...
# 58666   8720           NaN             NaN        NaN           NaN
# 58667   6488           NaN             NaN        NaN           NaN
# 58668    878           NaN             NaN        NaN           NaN
# 58669   4464           NaN             NaN        NaN           NaN
# 58670   4464           NaN             NaN        NaN           NaN
#
#       resource_type  log_feature  volume
# 0               NaN          NaN     NaN
# 1               NaN          NaN     NaN
# ...

# %%
# 2
inner = pd.merge(train,test, on='id', how='inner')
inner
# Out:
# Empty DataFrame
# Columns: [id, location_x, fault_severity, location_y]
# Index: []

# %%
outer = pd.merge(train,test, on='id', how='outer')
outer
# Out:
#           id    location_x  fault_severity     location_y
# 0      14121  location 118             1.0            NaN
# 1       9320   location 91             0.0            NaN
# 2      14394  location 152             1.0            NaN
# 3       8218  location 931             1.0            NaN
# 4      14804  location 120             0.0            NaN
# ...      ...           ...             ...            ...
# 18547  14806           NaN             NaN  location 1073
# 18548   1825           NaN             NaN    location 11
# 18549   2374           NaN             NaN   location 917
# 18550   7277           NaN             NaN   location 208
# 18551   9886           NaN             NaN   location 438
#
# [18552 rows x 4 columns]

# %% [markdown]
# The difference bewtween inner and outer is that inner only includes values that are common in both data frmaes while outer is including everything of each data frame.

# %%
# 3
joined = train.join(event, lsuffix='_l', rsuffix='_r')
joined
# Out:
#        id_l       location  fault_severity   id_r     event_type
# 0     14121   location 118               1   6597  event_type 11
# 1      9320    location 91               0   8011  event_type 15
# 2     14394   location 152               1   2597  event_type 15
# 3      8218   location 931               1   5022  event_type 15
# 4     14804   location 120               0   5022  event_type 11
# ...     ...            ...             ...    ...            ...
# 7376    870   location 167               0  17798  event_type 34
# 7377  18068   location 106               0   8027  event_type 34
# 7378  14111  location 1086               2   8027  event_type 35
# 7379  15189     location 7               0   7272  event_type 35
# 7380  17067   location 885               0   2179  event_type 35
#
# [7381 rows x 5 columns]

# %%
merged = pd.merge(train,event, on='id', how='left')
merged
# Out:
#           id       location  fault_severity     event_type
# 0      14121   location 118               1  event_type 34
# 1      14121   location 118               1  event_type 35
# 2       9320    location 91               0  event_type 34
# 3       9320    location 91               0  event_type 35
# 4      14394   location 152               1  event_type 35
# ...      ...            ...             ...            ...
# 12463    870   location 167               0  event_type 35
# 12464  18068   location 106               0  event_type 20
# 12465  14111  location 1086               2  event_type 15
# 12466  15189     location 7               0  event_type 11
# 12467  17067   location 885               0  event_type 11
#
# [12468 rows x 4 columns]

# %% [markdown]
# the difference between join and merge is that join combines the data frame on the key col or an index, while ther merge function joins based on the data frames common column or common indice. As shown up above.

# %%
# 4
train = train.iloc[0:10000]
event = event.iloc[10000:]
# 5
train_event = pd.concat([train, event], axis=1)
train_event
# Out:
#             id      location  fault_severity      id     event_type
# 0      14121.0  location 118             1.0     NaN            NaN
# 1       9320.0   location 91             0.0     NaN            NaN
# 2      14394.0  location 152             1.0     NaN            NaN
# 3       8218.0  location 931             1.0     NaN            NaN
# 4      14804.0  location 120             0.0     NaN            NaN
# ...        ...           ...             ...     ...            ...
# 31165      NaN           NaN             NaN  3761.0  event_type 11
# 31166      NaN           NaN             NaN  8720.0  event_type 11
# 31167      NaN           NaN             NaN  6488.0  event_type 11
# 31168      NaN           NaN             NaN   878.0  event_type 11
# 31169      NaN           NaN             NaN  4464.0  event_type 11
#
# [28551 rows x 5 columns]

# %%
# 6
train_event.duplicated(subset='id').sum() # the amount of duplicates
# Out:
# 8607

# %%
train_event_ndup =train_event.drop_duplicates(subset='id')

# %%
train_event_ndup.reset_index(drop=True)
# Out:
#             id      location  fault_severity      id     event_type
# 0      14121.0  location 118             1.0     NaN            NaN
# 1       9320.0   location 91             0.0     NaN            NaN
# 2      14394.0  location 152             1.0     NaN            NaN
# 3       8218.0  location 931             1.0     NaN            NaN
# 4      14804.0  location 120             0.0     NaN            NaN
# ...        ...           ...             ...     ...            ...
# 19939      NaN           NaN             NaN  3761.0  event_type 11
# 19940      NaN           NaN             NaN  8720.0  event_type 11
# 19941      NaN           NaN             NaN  6488.0  event_type 11
# 19942      NaN           NaN             NaN   878.0  event_type 11
# 19943      NaN           NaN             NaN  4464.0  event_type 11
#
# [19944 rows x 5 columns]
