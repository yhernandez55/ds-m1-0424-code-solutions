# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
# part 2 having the API key that was generated the movie database website
api_key = "e529ea32c8bd67623d3ddc7ab3210622"
api_key_rd_acess = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlNTI5ZWEzMmM4YmQ2NzYyM2QzZGRjN2FiMzIxMDYyMiIsInN1YiI6IjY2NDJiYzgxOTlkNjMxYjgzYjcwZGQ0NyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.wD5k2WivJaq0-1NIt9g-5yQAEVlOffRZtNmiMU62_Zs"
base_movie_url = f"https://api.themoviedb.org/3/search/movie?query=star&wars&include_adult=false&language=en-US&page=1&api_key={api_key}"
base_movie_url
# Out:
# 'https://api.themoviedb.org/3/search/movie?query=star&wars&include_adult=false&language=en-US&page=1&api_key=e529ea32c8bd67623d3ddc7ab3210622'

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlOGZjZTZiZjQ1MDAyYmJkODhkNjEzYjNmNGNjNzVhOCIsInN1YiI6IjY2NDJiYzgxOTlkNjMxYjgzYjcwZGQ0NyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.0veG11YXauMUBYgm5ljnQ4RDumpBthIl0iMi63LKyhI"
}

# %%
star_wars_data = requests.get(base_movie_url, headers)
star_wars_data.status_code
# Out:
# 200

# %%
star_wars_data.content
# Out:
# b'{"page":1,"results":[{"adult":false,"backdrop_path":"/hZ9JgBLCsYRYCU9jWkvTytWZzj8.jpg","genre_ids":[18,10749],"id":1276338,"original_language":"ta","original_title":"Star","overview":"Follows a youngster Kalai and his aspirations of becoming a \'Star\' in the Tamil Film Industry. Born in a lower-middle-class family, will Kalai overcome all his struggles to emerge as a Star?","popularity":16.707,"poster_path":"/6IMfsb1Io5VwofQ6dxJTHEAq1ho.jpg","release_date":"2024-05-10","title":"Star","video":false,"vote_average":0.0,"vote_count":0},{"adult":false,"backdrop_path":"/9LDPqWNV3RZiGFHVylNIpxbuOVN.jpg","genre_ids":[18,10402,10749],"id":52959,"original_language":"en","original_title":"Star!","overview":"Gertrude Lawrence rises to stage stardom at the cost of happiness.","popularity":23.867,"poster_path":"/xMyOm5hLWeuoWBea1DJrcJy8bU6.jpg","release_date":"1968-07-18","title":"Star!","video":false,"vote_average":6.4,"vote_count":127},{"adult":false,"backdrop_path":"/A55WRPRK73zx1cuULDkdX4vriDO.jpg","genre_ids":[35,28],"id":22599,"original_language":"en","original_title":"Star","overview":"The Driver now carries an arrogant rock star who is visiting a major city (not Pittsburgh as earlier believed). Played by Madonna, this title character wants to get away from her bodyguards in the Driver\'s BMW. He soon gets tired of her and decides to have a bit of fun.","popularity":8.51,"poster_path":"/zslEgrYEg6EDzOYrr8EfDoQK8j1.jpg","release_date":"2001-06-01","title":"Star","video":false,"vote_average":6.9,"vote_count":271},{"adult":false,"backdrop_path":"/a1lMRUeGozBAczWaSoU1p3zLmGs.jpg","genre_ids":[10749,18],"id":136244,"original_language":"en","original_title":"Star","overview":"When Crystal Wyatt was 16 her father passed away. From that time her life would never be the same. Crystal is banished from the family ranch, and starts a new life as a singer in a San Francisco nightclub.","popularity":11.196,"poster_path":"/jYmt7JBvAmRJ0FxPx2UayOQ1uOB.jpg","release_date":"1993-09-20","title":"Star","video":false,"vote_average":6.0,"vote_count":125},{"adult":false,"backdrop_path":"/osHpQQ5rcbmH41I4LQlPlprRGpk.jpg","genre_ids":[18,10751],"id":125225,"original_language":"hi","original_title":"Star","overview":"Dev Kumar Verma comes from a middle-class family and must find employment to support his dad and mom. Dev, however, has set his mind upon becoming a music sensation like Elvis Presley. He loses his job because of this, and refuses to work until and unless he gets a job to his liking, much to the dismay of his parents and his brother, Shiv Kumar. Dev does get employment at Charlie\'s Disco, where he meets with Maya and falls in love with her.  When Charlie\'s Disco\'s competitor, Rana, finds out about Dev, he wants to hire Dev, but Dev decides to continue to work with Charlie\'s Disco, as a result Dev and Charlie get a beating by Rana\'s men, and Dev is unable to sing. After recuperating, Dev is devastated to find out that Maya and Shiv Kumar are in love with each other. What impact will this have on Dev and his brother on one hand, and what of his career in music?","popularity":8.193,"poster_path":"/pU7oXmVdNPrzj2XOGIQ6ciMnH42.jpg","release_date":"1982-10-22","title":"Star","video":false,"vote_average":5.9,"vote_count":57},{"adult":false,"backdrop_path":null,"genre_ids":[16,10751,14],"id":1225239,"original_language":"en","original_title":"Star","overview":"Follows a humble stick figure named Star.","popularity":1.221,"poster_path":"/sr64OWe8aLAhuyRzVO5h2n48G8W.jpg","release_date":"2025-05-09","title":"Star","video":false,"vote_average":0.0,"vote_count":0},{"adult":false,"backdrop_path":"/zDImYTJiECn1b79segxKr382DSe.jpg","genre_ids":[18],"id":449430,"original_language":"fr","original_title":"Star","overview":"Star is a young graffiti writer, the best in his city, Paris. His reputation attracts him as much into art galleries than in the police precincts. Accused of vandalism, he faces jail. Despite the threat, he decides to go to Rome with his c ...

# %%
# part 3 w/out printing all pages
data = star_wars_data.json()
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/hZ9JgBLCsYRYCU9jWkvTytWZzj8.jpg',
#    'genre_ids': [18, 10749],
#    'id': 1276338,
#    'original_language': 'ta',
#    'original_title': 'Star',
#    'overview': "Follows a youngster Kalai and his aspirations of becoming a 'Star' in the Tamil Film Industry. Born in a lower-middle-class family, will Kalai overcome all his struggles to emerge as a Star?",
#    'popularity': 16.707,
#    'poster_path': '/6IMfsb1Io5VwofQ6dxJTHEAq1ho.jpg',
#    'release_date': '2024-05-10',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/9LDPqWNV3RZiGFHVylNIpxbuOVN.jpg',
#    'genre_ids': [18, 10402, 10749],
#    'id': 52959,
#    'original_language': 'en',
#    'original_title': 'Star!',
#    'overview': 'Gertrude Lawrence rises to stage stardom at the cost of happiness.',
#    'popularity': 23.867,
#    'poster_path': '/xMyOm5hLWeuoWBea1DJrcJy8bU6.jpg',
#    'release_date': '1968-07-18',
#    'title': 'Star!',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 127},
#   {'adult': False,
#    'backdrop_path': '/A55WRPRK73zx1cuULDkdX4vriDO.jpg',
#    'genre_ids': [35, 28],
#    'id': 22599,
#    'original_language': 'en',
#    'original_title': 'Star',
#    'overview': "The Driver now carries an arrogant rock star who is visiting a major city (not Pittsburgh as earlier believed). Played by Madonna, this title character wants to get away from her bodyguards in the Driver's BMW. He soon gets tired of her and decides to have a bit of fun.",
#    'popularity': 8.51,
#    'poster_path': '/zslEgrYEg6EDzOYrr8EfDoQK8j1.jpg',
#    'release_date': '2001-06-01',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 271},
#   {'adult': False,
#    'backdrop_path': '/a1lMRUeGozBAczWaSoU1p3zLmGs.jpg',
#    'genre_ids': [10749, 18],
#    'id': 136244,
#    'original_language': 'en',
#    'original_title': 'Star',
#    'overview': 'When Crystal Wyatt was 16 her father passed away. From that time her life would never be the same. Crystal is banished from the family ranch, and starts a new life as a singer in a San Francisco nightclub.',
#    'popularity': 11.196,
#    'poster_path': '/jYmt7JBvAmRJ0FxPx2UayOQ1uOB.jpg',
#    'release_date': '1993-09-20',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 6.0,
#    'vote_count': 125},
#   {'adult': False,
#    'backdrop_path': '/osHpQQ5rcbmH41I4LQlPlprRGpk.jpg',
#    'genre_ids': [18, 10751],
#    'id': 125225,
#    'original_language': 'hi',
#    'original_title': 'Star',
#    'overview': "Dev Kumar Verma comes from a middle-class family and must find employment to support his dad and mom. Dev, however, has set his mind upon becoming a music sensation like Elvis Presley. He loses his job because of this, and refuses to work until and unless he gets a job to his liking, much to the dismay of his parents and his brother, Shiv Kumar. Dev does get employment at Charlie's Disco, where he meets with Maya and falls in love with her.  When Charlie's Disco's competitor, Rana, finds out about Dev, he wants to hire Dev, but Dev decides to continue to work with Charlie's Disco, as a result Dev and Charlie get a beating by Rana's men, and Dev is unable to sing. After recuperating, Dev is devastated to find out that Maya and Shiv Kumar are in love with each other. What impact will this have on Dev and his brother on one hand, and what of his career in music?",
#    'popularity': 8.193,
#    'poster_path': '/pU7oXmVdNPrzj2XOGIQ6ciMnH42.jpg',
#    'release_date': '1982-10-22',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 57},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [16, 10751, 14],
#    'id': 1225239,
#    'original_language': 'en',
#    'original_title': 'Star',
#    'overview': 'Follows a humble stick figure named Star.',
#    'popularity': 1.221,
#    'poster_path': '/sr64OWe8aLAhuyRzVO5h2n48G8W.jpg',
#    'release_date': '2025-05-09',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/zDImYTJiECn1b79segxKr382DSe.jpg',
#    'genre_ids': [18],
#    'id': 449430,
#    'original_language': 'fr',
#    'original_title': 'Star',
#    'overview': 'Star is a young graffiti writer, the best in his city, Paris. His reputation attracts him as much into art galleries than in the police precincts. Accused of vandalism, he faces jail. Despite the threat, he decides to go to Rome with his crew in search of the meaning of his art.',
#    'popularity': 3.863,
#    'poster_path': '/zeGcw5pPVT4DhHrSLUDxE58QJQn.jpg',
#    'release_date': '2017-04-03',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 34},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [18],
#    'id': 812434,
#    'original_language': 'it',
#    'original_title': 'Star',
#    'overview': 'Giacomo is a low-level actor and voice actor with a great passion for acting. After another disappointing audition he has one last chance to get the part assigned',
#    'popularity': 4.505,
#    'poster_path': '/4oObDGDhycViadrRCC2XJwwXAcR.jpg',
#    'release_date': '2019-12-19',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 34},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99, 10402],
#    'id': 719316,
#    'original_language': 'en',
#    'original_title': 'Star',
#    'overview': 'Documentary short film and music video for MIKAL\'s song "Star", comprised of footage of the actual recording process of the song itself.',
#    'popularity': 6.687,
#    'poster_path': '/5o0GyNlILqVxfteo7l31wB5qD2X.jpg',
#    'release_date': '2017-01-23',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 34},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [18],
#    'id': 1050338,
#    'original_language': 'fr',
#    'original_title': 'Star',
#    'overview': 'Star follows the path of Tito and Jay, two brothers living in the Montreal neighborhood of Park Extension. Accompanying these young people in their daily life marked by complicity and intimidation, Star tackles themes dear to teenagers: identity and friendship.',
#    'popularity': 14.787,
#    'poster_path': None,
#    'release_date': '',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 31},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 611791,
#    'original_language': 'fr',
#    'original_title': 'Star',
#    'overview': 'Star follows the path of Tito and Jay, two brothers living in the Montreal neighborhood of Park Extension. Accompanying these young people in their daily life marked by complicity and intimidation, Star tackles themes dear to teenagers: identity and friendship.',
#    'popularity': 4.571,
#    'poster_path': '/hVGnSMBc42TGwvV5QTHpH0PgyJp.jpg',
#    'release_date': '2015-09-30',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 5.9,
#    'vote_count': 36},
#   {'adult': False,
#    'backdrop_path': '/4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 11,
#    'original_language': 'en',
#    'original_title': 'Star Wars',
#    'overview': 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker and dashing captain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.',
#    'popularity': 441.367,
#    'poster_path': '/6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg',
#    'release_date': '1977-05-25',
#    'title': 'Star Wars',
#    'video': False,
#    'vote_average': 8.2,
#    'vote_count': 19997},
#   {'adult': False,
#    'backdrop_path': '/6sZj7qhJy1IrFsNZujzNvedGJTm.jpg',
#    'genre_ids': [18, 10749],
#    'id': 1214525,
#    'original_language': 'en',
#    'original_title': 'Star',
#    'overview': 'In this experimental short film, a young man and woman enter into a relationship with one another and quickly learn the ups and downs of intertwining their life with the one they love.',
#    'popularity': 2.657,
#    'poster_path': '/nwspHrYoyuhxC3e6dEIBFDqhlGS.jpg',
#    'release_date': '2024-03-30',
#    'title': 'Star',
#    'video': False,
#    'vote_average': 10.0,
#    'vote_count': 1},
#   {'adult': False,
#    'backdrop_path': '/epVMXf10WqFkONzKR8V76Ypj5Y3.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 181808,
#    'original_language': 'en',
#    'original_title': 'Star Wars: The Last Jedi',
#    'overview': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares to do battle with the First Order.',
#    'popularity': 94.725,
#    'poster_path': '/kOVEVeg59E0wsnXmF9nrh6OmWII.jpg',
#    'release_date': '2017-12-13',
#    'title': 'Star Wars: The Last Jedi',
#    'video': False,
#    'vote_average': 6.805,
#    'vote_count': 14846},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 1005573,
#    'original_language': 'en',
#    'original_title': 'S.T.A.R.',
#    'overview': "Following the Stonewall riots, Trans activists Marsha P. Johnson and Sylvia Rivera opened S.T.A.R. house, the first LGBTQ+ youth shelter in the world. Soon after, they're faced with the reality that their battle for equality has to be waged on two fronts.",
#    'popularity': 4.893,
#    'poster_path': None,
#    'release_date': '',
#    'title': 'S.T.A.R.',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 26},
#   {'adult': False,
#    'backdrop_path': '/m4F1KRK5jAoQHi2mKDFE2jFKEIb.jpg',
#    'genre_ids': [28, 12, 878],
#    'id': 188927,
#    'original_language': 'en',
#    'original_title': 'Star Trek Beyond',
#    'overview': 'The USS Enterprise crew explores the furthest reaches of uncharted space, where they encounter a mysterious new enemy who puts them and everything the Federation stands for to the test.',
#    'popularity': 186.373,
#    'poster_path': '/yOnd3XQIg7JBmu0UuBjZyLdsxQD.jpg',
#    'release_date': '2016-07-07',
#    'title': 'Star Trek Beyond',
#    'video': False,
#    'vote_average': 6.786,
#    'vote_count': 6447},
#   {'adult': False,
#    'backdrop_path': '/jn52me8AagfNt7r84SgQbV0R9ZG.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 181812,
#    'original_language': 'en',
#    'original_title': 'Star Wars: The Rise of Skywalker',
#    'overview': 'The surviving Resistance faces the First Order once again as the journey of Rey, Finn and Poe Dameron continues. With the power and knowledge of generations behind them, the final battle begins.',
#    'popularity': 100.716,
#    'poster_path': '/db32LaOibwEliAmSL2jjDF6oDdj.jpg',
#    'release_date': '2019-12-18',
#    'title': 'Star Wars: The Rise of Skywalker',
#    'video': False,
#    'vote_average': 6.337,
#    'vote_count': 9524},
#   {'adult': False,
#    'backdrop_path': '/2kvl6lcgoyAaf8cSRkzxE611u6T.jpg',
#    'genre_ids': [16, 28, 14, 878],
#    'id': 761898,
#    'original_language': 'ja',
#    'original_title': '劇場版 ソードアート・オンライン-プログレッシブ- 星なき夜のアリア',
#    'overview': "One month after Kayaba Akihiko's game of death began, the death toll continues to rise, two thousand players having already lost their lives to the ultra-difficult VRMMO world of Sword Art Online. On the day of the strategy meeting to plan out the first-floor boss battle, Kirito, a solo player who vows to fight alone to get stronger, runs into a rare, high-level female player. She gracefully dispatches powerful monsters with a single rapier that flashes like a shooting star in the night...",
#    'popularity': 37.631,
#    'poster_path': '/yD9RhgIVydQNBK7OLEbCWYcWMUd.jpg',
#    'release_date': '2021-10-30',
#    'title': 'Sword Art Online the Movie – Progressive – Aria of a Starless Night',
#    'video': False,
#    'vote_average': 7.868,
#    'vote_count': 272},
#   {'adult': False,
#    'backdrop_path': '/eHKRUk1QENXXzrgKg3nLHJCQn4m.jpg',
#    'genre_ids': [16, 14],
#    'id': 1071101,
#    'original_language': 'ja',
#    'original_title': '大雪海のカイナ ほしのけんじゃ',
#    'overview': 'Kaina returns to the icy Canopy, unsure of what he should do next. He and Ririha have brought peace to Atland and Valghia through an alliance. Now supplies run low, and the people need answers. Kaina, Ririha, and their small party set out to cross the snow in search of the great orbital spire tree. This is the first step to saving their people. Join Kaina on an expedition to save mankind!',
#    'popularity': 19.778,
#    'poster_path': '/tknSJyInVeBZhaIUHlzPpqA45Ej.jpg',
#    'release_date': '2023-10-13',
#    'title': 'Kaina of the Great Snow Sea: Star Sage',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 3},
#   {'adult': False,
#    'backdrop_path': '/w9HSDuenuTKKhYTs7wYVqKdGVqf.jpg',
#    'genre_ids': [16, 14, 35, 28],
#    'id': 150434,
#    'original_language': 'ja',
#    'original_title': '映画 ふたりはプリキュア Splash☆Star チクタク危機一髪！',
#    'overview': "In the middle of a karaoke contest, Saki and Mai find that time has suddenly stopped. Following some spirits, they wind up in the Land of Clocks where they find Sirloin, a warrior from Dark Fall who is keeping the Infinite Clock hostage.  Naturally, Pretty Cure won't stand for this, and they begin to battle. But can they stop fighting with each other first?",
#    'popularity': 11.096,
#    'poster_path': '/4LNhz62BIwfDwQ5xoSWwz8EUJEq.jpg',
#    'release_date': '2006-12-09',
#    'title': 'Futari wa Precure Splash☆Star Tic-Tac Crisis Hanging by a Thin Thread!',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 18}],
#  'total_pages': 245,
#  'total_results': 4897}

# %%
response = requests.get(base_movie_url)
# this prints all pages for the movie star wars
# checking the sucess of the response
if response.status_code == 200:
    # Extracting data from the response
    data = response.json()

    # Print all the pages
    for page in data["results"]:
        print(page)
print(page)
print(data) # prints all the pages from the website
# Out:
# {'adult': False, 'backdrop_path': '/hZ9JgBLCsYRYCU9jWkvTytWZzj8.jpg', 'genre_ids': [18, 10749], 'id': 1276338, 'original_language': 'ta', 'original_title': 'Star', 'overview': "Follows a youngster Kalai and his aspirations of becoming a 'Star' in the Tamil Film Industry. Born in a lower-middle-class family, will Kalai overcome all his struggles to emerge as a Star?", 'popularity': 16.707, 'poster_path': '/6IMfsb1Io5VwofQ6dxJTHEAq1ho.jpg', 'release_date': '2024-05-10', 'title': 'Star', 'video': False, 'vote_average': 0.0, 'vote_count': 0}
# {'adult': False, 'backdrop_path': '/9LDPqWNV3RZiGFHVylNIpxbuOVN.jpg', 'genre_ids': [18, 10402, 10749], 'id': 52959, 'original_language': 'en', 'original_title': 'Star!', 'overview': 'Gertrude Lawrence rises to stage stardom at the cost of happiness.', 'popularity': 23.867, 'poster_path': '/xMyOm5hLWeuoWBea1DJrcJy8bU6.jpg', 'release_date': '1968-07-18', 'title': 'Star!', 'video': False, 'vote_average': 6.4, 'vote_count': 127}
# {'adult': False, 'backdrop_path': '/A55WRPRK73zx1cuULDkdX4vriDO.jpg', 'genre_ids': [35, 28], 'id': 22599, 'original_language': 'en', 'original_title': 'Star', 'overview': "The Driver now carries an arrogant rock star who is visiting a major city (not Pittsburgh as earlier believed). Played by Madonna, this title character wants to get away from her bodyguards in the Driver's BMW. He soon gets tired of her and decides to have a bit of fun.", 'popularity': 8.51, 'poster_path': '/zslEgrYEg6EDzOYrr8EfDoQK8j1.jpg', 'release_date': '2001-06-01', 'title': 'Star', 'video': False, 'vote_average': 6.9, 'vote_count': 271}
# {'adult': False, 'backdrop_path': '/a1lMRUeGozBAczWaSoU1p3zLmGs.jpg', 'genre_ids': [10749, 18], 'id': 136244, 'original_language': 'en', 'original_title': 'Star', 'overview': 'When Crystal Wyatt was 16 her father passed away. From that time her life would never be the same. Crystal is banished from the family ranch, and starts a new life as a singer in a San Francisco nightclub.', 'popularity': 11.196, 'poster_path': '/jYmt7JBvAmRJ0FxPx2UayOQ1uOB.jpg', 'release_date': '1993-09-20', 'title': 'Star', 'video': False, 'vote_average': 6.0, 'vote_count': 125}
# {'adult': False, 'backdrop_path': '/osHpQQ5rcbmH41I4LQlPlprRGpk.jpg', 'genre_ids': [18, 10751], 'id': 125225, 'original_language': 'hi', 'original_title': 'Star', 'overview': "Dev Kumar Verma comes from a middle-class family and must find employment to support his dad and mom. Dev, however, has set his mind upon becoming a music sensation like Elvis Presley. He loses his job because of this, and refuses to work until and unless he gets a job to his liking, much to the dismay of his parents and his brother, Shiv Kumar. Dev does get employment at Charlie's Disco, where he meets with Maya and falls in love with her.  When Charlie's Disco's competitor, Rana, finds out about Dev, he wants to hire Dev, but Dev decides to continue to work with Charlie's Disco, as a result Dev and Charlie get a beating by Rana's men, and Dev is unable to sing. After recuperating, Dev is devastated to find out that Maya and Shiv Kumar are in love with each other. What impact will this have on Dev and his brother on one hand, and what of his career in music?", 'popularity': 8.193, 'poster_path': '/pU7oXmVdNPrzj2XOGIQ6ciMnH42.jpg', 'release_date': '1982-10-22', 'title': 'Star', 'video': False, 'vote_average': 5.9, 'vote_count': 57}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [16, 10751, 14], 'id': 1225239, 'original_language': 'en', 'original_title': 'Star', 'overview': 'Follows a humble stick figure named Star.', 'popularity': 1.221, 'poster_path': '/sr64OWe8aLAhuyRzVO5h2n48G8W.jpg', 'release_date': '2025-05-09', 'title': 'Star', 'video': False, 'vote_average': 0.0, 'vote_count': 0}
# {'adult': False, 'backdrop_path': '/zDImYTJiECn1b79segxKr382DSe.jpg', 'genre_ids': [18], 'id': 449430, 'original_language': 'fr', 'original_title': 'Star', 'overview': 'Star is a young graffiti writer, the best in his city, Paris. His reputation attracts him as much into art galleries than in the police precincts. Accused of vandalism, he faces jail. Despite the threat, he decides to go to Rome with his crew in search of the meaning of his art.', 'popularity': 3.863, 'poster_path': '/zeGcw5pPVT4DhHrSLUDxE58QJQn.jpg', 'release_date': '2017-04-03', 'title': 'Star', 'video': False, 'vote_average': 5.9, 'vote_count': 34}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 812434, 'original_language': 'it', 'original_title': 'Star', 'overview': 'Giacomo is a low-level actor and voice actor with a great passion for acting. After another disappointing audition he has one last chance to get the part assigned', 'popularity': 4.505, 'poster_path': '/4oObDGDhycViadrRCC2XJwwXAcR.jpg', 'release_date': '2019-12-19', 'title': 'Star', 'video': False, 'vote_average': 6.3, 'vote_count': 34}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [99, 10402], 'id': 719316, 'original_language': 'en', 'original_title': 'Star', 'overview': 'Documentary short film and music video for MIKAL\'s song "Star", comprised of footage of the actual recording process of the song itself.', 'popularity': 6.687, 'poster_path': '/5o0GyNlILqVxfteo7l31wB5qD2X.jpg', 'release_date': '2017-01-23', 'title': 'Star', 'video': False, 'vote_average': 6.3, 'vote_count': 34}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 1050338, 'original_language': 'fr', 'original_title': 'Star', 'overview': 'Star follows the path of Tito and Jay, two brothers living in the Montreal neighborhood of Park Extension. Accompanying these young people in their daily life marked by complicity and intimidation, Star tackles themes dear to teenagers: identity and friendship.', 'popularity': 14.787, 'poster_path': None, 'release_date': '', 'title': 'Star', 'video': False, 'vote_average': 6.3, 'vote_count': 31}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 611791, 'original_language': 'fr', 'original_title': 'Star', 'overview': 'Star follows the path of Tito and Jay, two brothers living in the Montreal neighborhood of Park Extension. Accompanying these young people in their daily life marked by complicity and intimidation, Star tackles themes dear to teenagers: identity and friendship.', 'popularity': 4.571, 'poster_path': '/hVGnSMBc42TGwvV5QTHpH0PgyJp.jpg', 'release_date': '2015-09-30', 'title': 'Star', 'video': False, 'vote_average': 5.9, 'vote_count': 36}
# {'adult': False, 'backdrop_path': '/4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg', 'genre_ids': [12, 28, 878], 'id': 11, 'original_language': 'en', 'original_title': 'Star Wars', 'overview': 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker and dashing captain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.', 'popularity': 441.367, 'poster_path': '/6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg', 'release_date': '1977-05-25', 'title': 'Star Wars', 'video': False, 'vote_average': 8.2, 'vote_count': 19997}
# {'adult': False, 'backdrop_path': '/6sZj7qhJy1IrFsNZujzNvedGJTm.jpg', 'genre_ids': [18, 10749], 'id': 1214525, 'original_language': 'en', 'original_title': 'Star', 'overview': 'In this experimental short film, a young man and woman enter into a relationship with one another and quickly learn the ups and downs of intertwining their life with the one they love.', 'popularity': 2.657, 'poster_path': '/nwspHrYoyuhxC3e6dEIBFDqhlGS.jpg', 'release_date': '2024-03-30', 'title': 'Star', 'video': False, 'vote_average': 10.0, 'vote_count': 1}
# {'adult': False, 'backdrop_path': '/epVMXf10WqFkONzKR8V76Ypj5Y3.jpg', 'genre_ids': [12, 28, 878], 'id': 181808, 'original_language': 'en', 'original_title': 'Star Wars: The Last Jedi', 'overview': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares to do battle with the First Order.', 'popularity': 94.725, 'poster_path': '/kOVEVeg59E0wsnXmF9nrh6OmWII.jpg', 'release_date': '2017-12-13', 'title': 'Star Wars: The Last Jedi', 'video': False, 'vote_average': 6.805, 'vote_count': 14846}
# {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 1005573, 'original_language': 'en', 'original_title': 'S.T.A.R.', 'overview': "Following the Stonewall riots, Trans activists Marsha P. Johnson and Sylvia Rivera opened S.T.A.R. house, the first LGBTQ+ youth shelter in the world. Soon after, they're faced with the reality that their battle for equality has to be waged on two fronts.", 'popularity': 4.893, 'poster_path': None, 'release_date': '', 'title': 'S.T.A.R.', 'video': False, 'vote_average': 5.7, 'vote_count': 26}
# {'adult': False, 'backdrop_path': '/m4F1KRK5jAoQHi2mKDFE2jFKEIb.jpg', 'genre_ids': [28, 12, 878], 'id': 188927, 'original_language': 'en', 'original_title': 'Star Trek Beyond', 'overview': 'The USS Enterprise crew explores the furthest reaches of uncharted space, where they encounter a mysterious new enemy who puts them and everything the Federation stands for to the test.', 'popularity': 186.373, 'poster_path': '/yOnd3XQIg7JBmu0UuBjZyLdsxQD.jpg', 'release_date': '2016-07-07', 'title': 'Star Trek Beyond', 'video': False, 'vote_average': 6.786, 'vote_count': 6447}
# {'adult': False, 'backdrop_path': '/jn52me8AagfNt7r84SgQbV0R9ZG.jpg', 'genre_ids': [12, 28, 878], 'id': 181812, 'original_language': 'en', 'original_title': 'Star Wars: The Rise of Skywalker', 'overview': 'The surviving Resistance faces the First Order once again as the journey of Rey, Finn and Poe Dameron continues. With the power and knowledge of generations behind them, the final battle begins.', 'popularity': 100.716, 'poster_path': '/db32LaOibwEliAmSL2jjDF6oDdj.jpg', 'release_date': '2019-12-18', 'title': 'Star Wars: The Rise of Skywalker', 'video': False, 'vote_average': 6.337, 'vote_count': 9524}
# {'adult': False, 'backdrop_path': '/2kvl6lcgoyAaf8cSRkzxE611u6T.jpg', 'genre_ids': [16, 28, 14, 878], 'id': 761898, 'original_language': 'ja', 'original_title': '劇場版 ソードアート・オンライン-プログレッシブ- 星なき夜のアリア', 'overview': "One month after Kayaba Akihiko's game of death began, the death toll continues to rise, two thousand players having already lost their lives to the ultra-difficult VRMMO world of Sword Art Online. On the day of the strategy meeting to plan out the first-floor boss battle, Kirito, a solo player who vows to fight alone to get stronger, runs into a rare, high-level female player. She gracefully dispatches powerful monsters with a single rapier that flashes like a shooting star in the night...", 'popularity': 37.631, 'poster_path': '/yD9RhgIVydQNBK7OLEbCWYcWMUd.jpg', 'release_date': '2021-10-30', 'title': 'Sword Art Online the Movie – Progressive – Aria of a Starless Night', 'video': False, 'vote_average': 7.868, 'vote_count': 272}
# {'adult': False, 'backdrop_path': '/eHKRUk1QENXXzrgKg3nLHJCQn4m.jpg', 'genre_ids': [16, 14], 'id': 1071101, 'original_language': 'ja', 'original_title': '大雪海のカイナ ほしのけんじゃ', 'overview': 'Kaina returns to the icy Canopy, unsure of what he should do next. He and Ririha have brought peace to Atland and Valghia through an alliance. Now supplies run low, and the people need answers. Kaina, Ririha, and their small party set out to cross the snow in search of the great orbital spire tree. This is the first step to saving their people. Join Kaina on an expedition to save mankind!', 'popularity': 19.778, 'poster_path': '/tknSJyInVeBZhaIUHlzPpqA45Ej.jpg', 'release_date': '2023-10-13', 'title': 'Kaina of the Great Snow Sea: Star Sage', 'video': False, 'vote_average': 5.7, 'vote_count': 3}
# {'adult': False, 'backdrop_path': '/w9HSDuenuTKKhYTs7wYVqKdGVqf.jpg', 'genre_ids': [16, 14, 35, 28], 'id': 150434, 'original_language': 'ja', 'original_title': '映画 ふたりはプリキュア Splash☆Star チクタク危機一髪！', 'overview': "In the middle of a karaoke contest, Saki and Mai find that time has suddenly stopped. Following some spirits, they wind up in the Land of Clocks where they find Sirloin, a warrior from Dark Fall who is keeping the Infinite Clock hostage.  Naturally, Pretty Cure won't stand for this, and they begin to battle. But can they stop fighting with each other first?", 'popularity': 11.096, 'poster_path': '/4LNhz62BIwfDwQ5xoSWwz8EUJEq.jpg', 'release_date': '2006-12-09', 'title': 'Futari wa Precure Splash☆Star Tic-Tac Crisis Hanging by a Thin Thread!', 'video': False, 'vote_average': 6.9, 'vote_count': 18}
# {'adult': False, 'backdrop_path': '/w9HSDuenuTKKhYTs7wYVqKdGVqf.jpg', 'genre_ids': [16, 14, 35, 28], 'id': 150434, 'original_language': 'ja', 'original_title': '映画 ふたりはプリキュア Splash☆Star チクタク危機一髪！', 'overview': "In the middle of a karaoke contest, Saki and Mai find that time has suddenly stopped. Following some spirits, they wind up in the Land of Clocks where they find Sirloin, a warrior from Dark Fall who is keeping the Infinite Clock hostage.  Naturally, Pretty Cure won't stand for this, and they begin to battle. But can they stop fighting with each other first?", 'popularity': 11.096, 'poster_path': '/4LNhz62BIwfDwQ5xoSWwz8EUJEq.jpg', 'release_date': '2006-12-09', 'title': 'Futari wa Precure Splash☆Star Tic-Tac Crisis Hanging by a Thin Thread!', 'video': False, 'vote_average': 6.9, 'vote_count': 18}
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/hZ9JgBLCsYRYCU9jWkvTytWZzj8.jpg', 'genre_ids': [18, 10749], 'id': 1276338, 'original_language': 'ta', 'original_title': 'Star', 'overview': "Follows a youngster Kalai and his aspirations of becoming a 'Star' in the Tamil Film Industry. Born in a lower-middle-class family, will Kalai overcome all his struggles to emerge as a Star?", 'popularity': 16.707, 'poster_path': '/6IMfsb1Io5VwofQ6dxJTHEAq1ho.jpg', 'release_date': '2024-05-10', 'title': 'Star', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/9LDPqWNV3RZiGFHVylNIpxbuOVN.jpg', 'genre_ids': [18, 10402, 10749], 'id': 52959, 'original_language': 'en', 'original_title': 'Star!', 'overview': 'Gertrude Lawrence rises to stage stardom at the cost of happiness.', 'popularity': 23.867, 'poster_path': '/xMyOm5hLWeuoWBea1DJrcJy8bU6.jpg', 'release_date': '1968-07-18', 'title': 'Star!', 'video': False, 'vote_average': 6.4, 'vote_count': 127}, {'adult': False, 'backdrop_path': '/A55WRPRK73zx1cuULDkdX4vriDO.jpg', 'genre_ids': [35, 28], 'id': 22599, 'original_language': 'en', 'original_title': 'Star', 'overview': "The Driver now carries an arrogant rock star who is visiting a major city (not Pittsburgh as earlier believed). Played by Madonna, this title character wants to get away from her bodyguards in the Driver's BMW. He soon gets tired of her and decides to have a bit of fun.", 'popularity': 8.51, 'poster_path': '/zslEgrYEg6EDzOYrr8EfDoQK8j1.jpg', 'release_date': '2001-06-01', 'title': 'Star', 'video': False, 'vote_average': 6.9, 'vote_count': 271}, {'adult': False, 'backdrop_path': '/a1lMRUeGozBAczWaSoU1p3zLmGs.jpg', 'genre_ids': [10749, 18], 'id': 136244, 'original_language': 'en', 'original_title': 'Star', 'overview': 'When Crystal Wyatt was 16 her father passed away. From that time her life would never be the same. Crystal is banished from the family ranch, and starts a new life as a singer in a San Francisco nightclub.', 'popularity': 11.196, 'poster_path': '/jYmt7JBvAmRJ0FxPx2UayOQ1uOB.jpg', 'release_date': '1993-09-20', 'title': 'Star', 'video': False, 'vote_average': 6.0, 'vote_count': 125}, {'adult': False, 'backdrop_path': '/osHpQQ5rcbmH41I4LQlPlprRGpk.jpg', 'genre_ids': [18, 10751], 'id': 125225, 'original_language': 'hi', 'original_title': 'Star', 'overview': "Dev Kumar Verma comes from a middle-class family and must find employment to support his dad and mom. Dev, however, has set his mind upon becoming a music sensation like Elvis Presley. He loses his job because of this, and refuses to work until and unless he gets a job to his liking, much to the dismay of his parents and his brother, Shiv Kumar. Dev does get employment at Charlie's Disco, where he meets with Maya and falls in love with her.  When Charlie's Disco's competitor, Rana, finds out about Dev, he wants to hire Dev, but Dev decides to continue to work with Charlie's Disco, as a result Dev and Charlie get a beating by Rana's men, and Dev is unable to sing. After recuperating, Dev is devastated to find out that Maya and Shiv Kumar are in love with each other. What impact will this have on Dev and his brother on one hand, and what of his career in music?", 'popularity': 8.193, 'poster_path': '/pU7oXmVdNPrzj2XOGIQ6ciMnH42.jpg', 'release_date': '1982-10-22', 'title': 'Star', 'video': False, 'vote_average': 5.9, 'vote_count': 57}, {'adult': False, 'backdrop_path': None, 'genre_ids': [16, 10751, 14], 'id': 1225239, 'original_language': 'en', 'original_title': 'Star', 'overview': 'Follows a humble stick figure named Star.', 'popularity': 1.221, 'poster_path': '/sr64OWe8aLAhuyRzVO5h2n48G8W.jpg', 'release_date': '2025-05-09', 'title': 'Star', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/zDImYTJiECn1b79segxKr382DSe.jpg', 'genre_ids': [18], 'id': 449430, 'original_language': 'fr', 'original_title': 'Star', 'overview': 'Star is a young graffiti writer, the best in his city, Pa ...

# %%
# part 4
# Extracting movies
movies = data["results"]


df = pd.DataFrame(movies)

# sorting throu popularity
df_sorted = df.sort_values(by='popularity', ascending=False)

# Print the sorted DataFrame
print(df_sorted)
# Out:
#     adult                     backdrop_path           genre_ids       id  \
# 11  False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg       [12, 28, 878]       11
# 15  False  /m4F1KRK5jAoQHi2mKDFE2jFKEIb.jpg       [28, 12, 878]   188927
# 16  False  /jn52me8AagfNt7r84SgQbV0R9ZG.jpg       [12, 28, 878]   181812
# 13  False  /epVMXf10WqFkONzKR8V76Ypj5Y3.jpg       [12, 28, 878]   181808
# 17  False  /2kvl6lcgoyAaf8cSRkzxE611u6T.jpg   [16, 28, 14, 878]   761898
# 1   False  /9LDPqWNV3RZiGFHVylNIpxbuOVN.jpg  [18, 10402, 10749]    52959
# 18  False  /eHKRUk1QENXXzrgKg3nLHJCQn4m.jpg            [16, 14]  1071101
# 0   False  /hZ9JgBLCsYRYCU9jWkvTytWZzj8.jpg         [18, 10749]  1276338
# 9   False                              None                [18]  1050338
# 3   False  /a1lMRUeGozBAczWaSoU1p3zLmGs.jpg         [10749, 18]   136244
# 19  False  /w9HSDuenuTKKhYTs7wYVqKdGVqf.jpg    [16, 14, 35, 28]   150434
# 2   False  /A55WRPRK73zx1cuULDkdX4vriDO.jpg            [35, 28]    22599
# 4   False  /osHpQQ5rcbmH41I4LQlPlprRGpk.jpg         [18, 10751]   125225
# 8   False                              None         [99, 10402]   719316
# 14  False                              None                  []  1005573
# 10  False                              None                  []   611791
# 7   False                              None                [18]   812434
# 6   False  /zDImYTJiECn1b79segxKr382DSe.jpg                [18]   449430
# 12  False  /6sZj7qhJy1IrFsNZujzNvedGJTm.jpg         [18, 10749]  1214525
# 5   False                              None     [16, 10751, 14]  1225239
#
#    original_language                      original_title  \
# 11                en                           Star Wars
# 15                en                    Star Trek Beyond
# 16                en    Star Wars: The Rise of Skywalker
# 13                en            Star Wars: The Last Jedi
# 17                ja  劇場版 ソードアート・オンライン-プログレッシブ- 星なき夜のアリア
# 1                 en                               Star!
# 18                ja                     大雪海のカイナ ほしのけんじゃ
# 0                 ta                                Star
# 9                 fr                                Star
# 3                 en                                Star
# 19                ja  映画 ふたりはプリキュア Splash☆Star チクタク危機一髪！
# 2                 en                                Star
# 4                 hi                                Star
# 8                 en                                Star
# 14                en                            S.T.A.R.
# 10                fr                                Star
# 7                 it                                Star
# 6                 fr                                Star
# 12                en                                Star
# 5                 en                                Star
#
#                                              overview  popularity  \
# 11  Princess Leia is captured and held hostage by ...     441.367
# 15  The USS Enterprise crew explores the furthest ...     186.373
# 16  The surviving Resistance faces the First Order...     100.716
# 13  Rey develops her newly discovered abilities wi...      94.725
# 17  One month after Kayaba Akihiko's game of death...      37.631
# 1   Gertrude Lawrence rises to stage stardom at th...      23.867
# 18  Kaina returns to the icy Canopy, unsure of wha...      19.778
# 0   Follows a youngster Kalai and his aspirations ...      16.707
# 9   Star follows the path of Tito and Jay, two bro...      14.787
# 3   When Crystal Wyatt was 16 her father passed aw...      11.196
# 19  In the middle of a karaoke contest, Saki and M...      11.096
# 2   The Driver now carries an arrogant rock star w...       8.510
# 4   Dev Kumar Verma comes from a middle-class fami...       8.193
# 8   Documentary short film and music video for MIK...       6.687
# 14  Following the Stonewall riots, Trans activists...       4.893
# 10  Star follows the path of Tito and Jay, two bro...       4.571
# 7   Giacomo is a low-level actor and voice actor w...       4.505
# 6   Star is a young graffiti writer, the best in h...       3.863
# 12  In this experimental short film, a young man a...       2.657
# 5           Follows a humble stick figure named Star.       1.221
#
#                          poster_path release_date  \
# 11  /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# 15  /yOnd3XQIg7JBmu0UuBjZyLdsxQD.jpg   2016-07-07
# 16  /db32LaOibwEliAmSL2jjDF6oDdj.jpg   2019-12-18
# 13  /kOVEVeg59E0wsnXmF9nrh6OmWII.jpg   2017-12-13
# 17  /yD9RhgIVydQNBK7OLEbCWYcWMUd.jpg   2021-10-30
# 1   /xMyOm5hLWeuoWBea1DJrcJy8bU6.jpg   1968-07-18
# 18  /tknSJyInVeBZhaIUHlzPpqA45Ej.jpg   2023-10-13
# 0   /6IMfsb1Io5VwofQ6dxJTHEAq1ho.jpg   2024-05-10
# 9                               None
# 3   /jYmt7JBvAmRJ0FxPx2UayOQ1uOB.jpg   1993-09-20
# 19  /4LNhz62BIwfDwQ5xoSWwz8EUJEq.jpg   2006-12-09
# 2   /zslEgrYEg6EDzOYrr8EfDoQK8j1.jpg   2001-06-01
# 4   /pU7oXmVdNPrzj2XOGIQ6ciMnH42.jpg   1982-10-22
# 8   /5o0GyNlILqVxfteo7l31wB5qD2X.jpg   2017-01-23
# 14                              None
# 10  /hVGnSMBc42TGwvV5QTHpH0PgyJp.jpg   2015-09-30
# 7   /4oObDGDhycViadrRCC2XJwwXAcR.jpg   2019-12-19
# 6   /zeGcw5pPVT4DhHrSLUDxE58QJQn.jpg   2017-04-03
# 12  /nwspHrYoyuhxC3e6dEIBFDqhlGS.jpg   2024-03-30
# 5   /sr64OWe8aLAhuyRzVO5h2n48G8W.jpg   2025-05-09
#
#                                                 title  video  vote_average  \
# 11                                          Star Wars  False         8.200
# 15                                   Star Trek Beyond  False         6.786
# 16                   Star Wars: The Rise of Skywalker  False         6.337
# 13                           Star Wars: The Last Jedi  False         6.805
# 17  Sword Art Online the Movie – Progressive – Ari...  False         7.868
# 1                                               Star!  False         6.400
# 18             Kaina of the Great Snow Sea: Star Sage  False         5.700
# 0                                                Star  False         0.000
# 9                                                Star  False         6.300
# 3                                                Star  False         6.000
# 19  Futari wa Precure Splash☆Star Tic-Tac Crisis H...  False         6.900
# 2                                                Star  False         6.900
# 4                                                Star  False         5.900
# 8                                                Star  False         6.300
# 14                                           S.T.A.R.  False         5.700
# 10                                               Star  False         5.900
# 7                                                Star  False         6.300
# 6                                                Star  False         5.900
# 12                                               Star  False        10.000
# 5                                                Star  False         0.000
#
#     vote_count
# 11       19997
# 15        6447
# 16        9524
# 13       14846
# 17         272
# 1          127
# 18           3
# 0            0
# 9           31
# 3          125
# 19          18
# 2          271
# 4           57
# 8           34
# 14          26
# 10          36
# 7           34
# 6           34
# 12           1
# 5            0
